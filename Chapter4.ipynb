# %% [markdown]
# <a href="https://colab.research.google.com/github/disha9213/Python-Summer-Training/blob/main/Chapter4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
a= [1,2,3,4,5]
print('The size of list is:-', sys.getsizeof(a))

# %%
import numpy as np
a =np.array([1,2,3,4,5])
print('The size of the array is ', a.itemsize)
# Out:
# The size of the array is  8

# %% [markdown]
# PANDAS

# %%
import pandas as pd

# %%
import pandas as pd
path = '/content/drive/MyDrive/Colab Notebooks/DataSet/Copy of imdb_data.csv'
df = pd.read_csv(path)
df.head() #Prints first 5 rows of the dataset :By default
#df ->>> data frame
#or df.head(2) for two rows
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %% [markdown]
# # **head()**
#
# ## Prints the first  n  rows of the dataframe. By default it prints the first 5 rows

# %%
df.head(2)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
#
#                                               genres homepage    imdb_id  \
# 0                     [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  tt0368933
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
#
#   release_date runtime                          spoken_languages    status  \
# ...

# %% [markdown]
# # **tail()**
# ## Prints the last  n  rows of the dataframe. By default it prints the last 5 rows

# %%
df.tail()
# Out:
#         id belongs_to_collection    budget  \
# 2995  2996                   NaN         0
# 2996  2997                   NaN         0
# 2997  2998                   NaN  65000000
# 2998  2999                   NaN  42000000
# 2999  3000                   NaN  35000000
#
#                                                  genres  \
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                               homepage    imdb_id original_language  \
# 2995                               NaN  tt0109403                en
# 2996                               NaN  tt2364975                sv
# 2997                               NaN  tt0116908                en
# 2998    http://www.alongcamepolly.com/  tt0343135                en
# ...

# %% [markdown]
# # **COLUMNS**
# ## Prints the list of columns in a dataframe

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %% [markdown]
# # **Info**
# ## Prints the basic information about our dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %% [markdown]
# # **DESCRIBE FUNCTION**
# ### This method gives the overall descriptive summary of the dataframe. This works only for numerical columns

# %%
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %% [markdown]
# # **Slicing In Pandas**

# %%
#df.iloc(rows,columns)
df.iloc[:5,3:5]
# Out:
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage
# 0                                NaN
# 1                                NaN
# 2  http://sonyclassics.com/whiplash/
# 3         http://kahaanithefilm.com/
# 4                                NaN

# %% [markdown]
# # **LOC METHOD**
# ## loc gets rows (or columns) with particular labels from the index.

# %%
df.loc[:5,['title','runtime','revenue']]
# Out:
#                                       title  runtime   revenue
# 0                    Hot Tub Time Machine 2     93.0  12314651
# 1  The Princess Diaries 2: Royal Engagement    113.0  95149435
# 2                                  Whiplash    105.0  13092000
# 3                                   Kahaani    122.0  16000000
# 4                                Marine Boy    118.0   3923970
# 5    Pinocchio and the Emperor of the Night     83.0   3261638

# %%
df[['title','runtime','revenue']]
# Out:
#                                          title  runtime    revenue
# 0                       Hot Tub Time Machine 2     93.0   12314651
# 1     The Princess Diaries 2: Royal Engagement    113.0   95149435
# 2                                     Whiplash    105.0   13092000
# 3                                      Kahaani    122.0   16000000
# 4                                   Marine Boy    118.0    3923970
# ...                                        ...      ...        ...
# 2995                                   Chasers    102.0    1596687
# 2996                          We Are the Best!    102.0     180590
# 2997                   The Long Kiss Goodnight    120.0   89456761
# 2998                          Along Came Polly     90.0  171963386
# 2999                                 Abduction    106.0   82087155
#
# [3000 rows x 3 columns]

# %% [markdown]
# FILTERS

# %%
#containing hindi movies only
hindi_movies = df[df['original_language'] == 'hi'][['title','runtime','revenue','original_language']]
hindi_movies.head() #for 1st five hindi movies
# Out:
#                                 title  runtime   revenue original_language
# 3                             Kahaani    122.0  16000000                hi
# 213                     Rowdy Rathore    143.0  31000000                hi
# 371                         Thank You    140.0   4100000                hi
# 401        The Legend of Bhagat Singh    155.0   6000000                hi
# 419  Dear Guest, When Will You Leave?    155.0   5000000                hi

# %%
hindi_movies.shape   #42 rows in hindi dataset
# Out:
# (42, 4)

# %%
#movie with runtime 338 min
df[df['runtime'] == 338]
#with limited features
df[df['runtime'] == 338][['title','runtime','revenue','original_language']]
# Out:
#        title  runtime  revenue original_language
# 1211  Carlos    338.0   871279                en

# %% [markdown]
# CREATING NEW COLUMNS IN EXISTING DATASET

# %%
df['runtime']
# Out:
# 0        93.0
# 1       113.0
# 2       105.0
# 3       122.0
# 4       118.0
#         ...
# 2995    102.0
# 2996    102.0
# 2997    120.0
# 2998     90.0
# 2999    106.0
# Name: runtime, Length: 3000, dtype: float64

# %%
#half runtime
df['half_runtime'] = df['runtime']/2 #or multiply by 0.5
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
#movies with max profit and min profit
df.columns
df['profit'  == max('profit')] = df['revenue'] - df['budget']
df['profit'] == max('profit')
df['profit']
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %% [markdown]
# # **DROP A COLUMN**

# %%
df.columns
df.drop(['half_runtime'],axis =1,inplace = True)  #inplace = true for permanently
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %% [markdown]
# ASCENDING AND DESCENDING

# %%
df.sort_values(by='profit' ,ascending= False)[['title','profit']]  #true or false as per requirement
# Out:
#                                             title      profit
# 1761                                    Furious 7  1316249360
# 1126                                 The Avengers  1299557910
# 2770                      Avengers: Age of Ultron  1125403694
# 684                          Beauty and the Beast  1102886337
# 2322               Transformers: Dark of the Moon   928746996
# ...                                           ...         ...
# 776                                     Australia   -80445998
# 307                                 Live by Night   -85321445
# 251                              Cutthroat Island   -87982678
# 2278                 The Adventures of Pluto Nash   -92896027
# 2623  Valerian and the City of a Thousand Planets  -107447384
#
# [3000 rows x 2 columns]

# %% [markdown]
# MAX PROFIT

# %%
df.profit
df['profit'].max()
df['profit'].min()
df['profit'].mean()
df['profit'].median()
df['profit'].mode()
# Out:
# 0    0
# Name: profit, dtype: int64

# %% [markdown]
# DATETIME FUNCTION

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   datetime64[ns]
# ...

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   datetime64[ns]
# ...

# %%
df['release_date'][0]
# Out:
# Timestamp('2015-02-20 00:00:00')

# %%
df['release_date'][0].month
# Out:
# 2

# %%
df['release_date'][0].day_name()
# Out:
# 'Friday'

# %%
df['release_date'][0].hour
# Out:
# 0

# %%
df['year'] = df['release_date'].dt.year
df['month'] = df['release_date'].dt.month
df['date'] = df['release_date'].dt.date
df['day_name'] = df['release_date'][0].day_name()
df['hour'] = df['release_date'].dt.hour
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   datetime64[ns]
# ...

# %%
df['original_language'].unique()
# Out:
# array(['en', 'hi', 'ko', 'sr', 'fr', 'it', 'nl', 'zh', 'es', 'cs', 'ta',
#        'cn', 'ru', 'tr', 'ja', 'fa', 'sv', 'de', 'te', 'pt', 'mr', 'da',
#        'fi', 'el', 'ur', 'he', 'no', 'ar', 'nb', 'ro', 'vi', 'pl', 'hu',
#        'ml', 'bn', 'id'], dtype=object)

# %%
df['original_language'].nunique() #no of languages in movies
# Out:
# 36

# %% [markdown]
# # **COUNT : HOW MANY MOVIES ARE THERE**
#
# # *  unique()
# # *  nunique()
# # *   value_counts()
# # *   isnull()
# # *   fillna()

# %%
df['original_language'].value_counts()
# Out:
# original_language
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# ko      20
# cn      20
# zh      19
# de      18
# ta      16
# sv       8
# pt       6
# nl       6
# fa       5
# da       5
# ro       4
# hu       3
# tr       3
# no       2
# te       2
# pl       2
# fi       2
# ml       2
# sr       1
# cs       1
# mr       1
# ar       1
# he       1
# ur       1
# el       1
# vi       1
# nb       1
# bn       1
# id       1
# Name: count, dtype: int64

# %% [markdown]
# ISNULL :TELL NULL VALUES IN A SPECIFIC COLUMN

# %%
df.isnull().sum()
# Out:
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# profit                      0
# False                       0
# year                        0
# month                       0
# date                        0
# day_name                    0
# hour                        0
# dtype: int64

# %%
df['belongs_to_collection'].fillna('not present',inplace = True)
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                        not present   3300000
# 3   4                                        not present   1200000
# 4   5                                        not present         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...
